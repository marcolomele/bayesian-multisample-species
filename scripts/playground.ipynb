# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/marcolomele/Documents/Repos/bayesian-multisample/data/namesbystate.csv')

# %%
df[df['state'].isin(['CA', 'TX', 'NY', 'FL', 'PA'])].to_csv('/Users/marcolomele/Documents/Repos/bayesian-multisample/data/namesbystate_subset.csv', index=False)
